# %%
import pandas as pd
df= pd.read_excel("data/dead_conso-3-54-65.xlsx")
df
# Out:
#              id  DEAD_YEAR(Budha)  DEAD_YEAR   Age  Sex NationalityId  \
# 0       8600677              2554       2011  72.0  1.0            99
# 1       8600520              2554       2011  17.0  1.0            99
# 2       8600600              2554       2011  44.0  1.0            99
# 3       8600625              2554       2011  43.0  1.0            99
# 4       8600681              2554       2011  35.0  1.0            99
# ...         ...               ...        ...   ...  ...           ...
# 238394  1072503              2565       2022  20.0  1.0           NaN
# 238395  1076343              2565       2022  66.0  1.0           NaN
# 238396  1078903              2565       2022  70.0  2.0           NaN
# 238397  1082487              2565       2022  65.0  1.0           NaN
# 238398  1078648              2565       2022  71.0  1.0           NaN
#
#              Tumbol        District Province  RiskHelmet  ...  \
# 0           วังหลวง  กิ่ง อ.เฝ้าไร่       นค         NaN  ...
# ...
